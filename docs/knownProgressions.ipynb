# %% [markdown]
# ## Plotting all known progressions

# %%
from jazzElements.progression import Progression,progressions
# %matplotlib inline

for song in progressions:
    prg = Progression(song)
    prg.annotate()
    prg.plot('fn')
